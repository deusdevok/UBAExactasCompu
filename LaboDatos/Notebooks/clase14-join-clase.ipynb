# %%
import pandas as pd
import sqlite3
import numpy as np

# %%
# !pip install fastparquet

# %% [markdown]
# # Joins en SQL

# %% [markdown]
# ## Ejemplo: viajes en taxi en Nueva York
#
# Fuente: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page

# %%
# Base de datos de viajes en enero de 2025 en Nueva York
trips = pd.read_parquet("yellow_tripdata_2025-01.parquet")
trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 3475221         2  2025-01-31 23:01:48   2025-01-31 23:16:29              NaN
# 3475222         2  2025-01-31 23:50:29   2025-02-01 00:17:27              NaN
# 3475223         2  2025-01-31 23:26:59   2025-01-31 23:43:01              NaN
# 3475224         2  2025-01-31 23:14:34   2025-01-31 23:34:52              NaN
# 3475225         2  2025-01-31 23:56:42   2025-02-01 00:07:27              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.60         1.0                  N           229
# 1                 0.50         1.0                  N           236
# 2                 0.60         1.0                  N           141
# 3                 0.52         1.0                  N           244
# 4                 0.66         1.0                  N           244
# ...                ...         ...                ...           ...
# 3475221           3.35         NaN               None            79
# 3475222           8.73         NaN               None           161
# 3475223           2.64         NaN               None           144
# 3475224           3.16         NaN               None           142
# 3475225           2.29         NaN               None           237
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 237             1        10.00    3.5      0.5        3.00
# 1                 237             1         5.10    3.5      0.5        2.02
# 2                 141             1         5.10    3.5      0.5        2.00
# 3                 244             2         7.20    1.0      0.5        0.00
# 4                 116             2         5.80    1.0      0.5        0.00
# ...               ...           ...          ...    ...      ...         ...
# 3475221           237             0        15.85    0.0      0.5        0.00
# 3475222           116             0        28.14    0.0      0.5        0.00
# 3475223           246             0        14.91    0.0      0.5        0.00
# 3475224           107             0        17.55    0.0      0.5        0.00
# 3475225           238             0        12.09    0.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    1.0         18.00
# 1                 0.0                    1.0         12.12
# 2                 0.0                    1.0         12.10
# 3                 0.0                    1.0          9.70
# 4                 0.0                    1.0          8.30
# ...               ...                    ...           ...
# 3475221           0.0                    1.0         20.60
# 3475222           0.0                    1.0         32.89
# 3475223           0.0                    1.0         19.66
# 3475224           0.0                    1.0         22.30
# 3475225           0.0                    1.0         16.09
#
#          congestion_surcharge  Airport_fee  cbd_congestion_fee
# 0                         2.5          0.0                0.00
# 1                         2.5          0.0                0.00
# 2                         2.5          0.0                0.00
# 3                         0.0          0.0                0.00
# 4                         0.0          0.0                0.00
# ...                       ...          ...                 ...
# 3475221                   NaN          NaN                0.75
# 3475222                   NaN          NaN                0.75
# 3475223                   NaN          NaN                0.75
# 3475224                   NaN          NaN                0.75
# 3475225                   NaN          NaN                0.00
#
# [3475226 rows x 20 columns]

# %% [markdown]
# La base contiene ID del lugar de Pick-up (subida) e ID del lugar de Drop-Off (bajada).
#
# La información sobre cada ID la tenemos en una tabla de zonas.

# %%
zones = pd.read_csv("taxi_zone_lookup.csv")
zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
# Vemos los barrios
zones.Borough.value_counts()
# Out:
# Borough
# Queens           69
# Manhattan        69
# Brooklyn         61
# Bronx            43
# Staten Island    20
# EWR               1
# Unknown           1
# Name: count, dtype: int64

# %%
# Para no trabajar con tantos datos nos quedamos solo con los viajes del 1 de enero
trips = trips[trips.tpep_pickup_datetime.dt.day == 1]
trips
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1               1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2               1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3               2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4               2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...           ...                  ...                   ...              ...
# 2950896         2  2025-01-01 23:41:33   2025-01-01 23:58:46              NaN
# 2950897         2  2025-01-01 23:02:52   2025-01-01 23:08:01              NaN
# 2950898         2  2025-01-01 23:33:52   2025-01-01 23:48:39              NaN
# 2950899         2  2025-01-01 23:34:59   2025-01-01 23:51:28              NaN
# 2950900         2  2025-01-01 23:28:31   2025-01-01 23:51:27              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.60         1.0                  N           229
# 1                 0.50         1.0                  N           236
# 2                 0.60         1.0                  N           141
# 3                 0.52         1.0                  N           244
# 4                 0.66         1.0                  N           244
# ...                ...         ...                ...           ...
# 2950896           6.09         NaN               None           197
# 2950897           0.97         NaN               None           170
# 2950898           6.00         NaN               None           219
# 2950899           3.59         NaN               None           215
# 2950900          13.32         NaN               None            28
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 237             1        10.00    3.5      0.5        3.00
# 1                 237             1         5.10    3.5      0.5        2.02
# 2                 141             1         5.10    3.5      0.5        2.00
# 3                 244             2         7.20    1.0      0.5        0.00
# 4                 116             2         5.80    1.0      0.5        0.00
# ...               ...           ...          ...    ...      ...         ...
# 2950896            36             0         2.94    0.0      0.5        0.00
# 2950897           234             0        -0.71    0.0      0.5        0.00
# 2950898            86             0        -3.34    0.0      0.5        0.00
# 2950899           258             0        -0.94    0.0      0.5        0.00
# 2950900           242             0       -11.86    0.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         18.00
# 1                0.00                    1.0         12.12
# 2                0.00                    1.0         12.10
# 3                0.00                    1.0          9.70
# 4                0.00                    1.0          8.30
# ...               ...                    ...           ...
# 2950896          0.00                    1.0          4.44
# 2950897          0.00                    1.0          3.29
# 2950898          0.00                    1.0         -1.84
# 2950899          0.00                    1.0          3.06
# 2950900          6.94                    1.0         -3.42
#
#          congestion_surcharge  Airport_fee  cbd_congestion_fee
# 0                         2.5          0.0                 0.0
# 1                         2.5          0.0                 0.0
# 2                         2.5          0.0                 0.0
# 3                         0.0          0.0                 0.0
# 4                         0.0          0.0                 0.0
# ...                       ...          ...                 ...
# 2950896                   NaN          NaN                 0.0
# 2950897                   NaN          NaN                 0.0
# 2950898                   NaN          NaN                 0.0
# 2950899                   NaN          NaN                 0.0
# 2950900                   NaN          NaN                 0.0
#
# [90189 rows x 20 columns]

# %%
trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90189 entries, 0 to 2950900
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               90189 non-null  int32
#  1   tpep_pickup_datetime   90189 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  90189 non-null  datetime64[us]
#  3   passenger_count        74365 non-null  float64
#  4   trip_distance          90189 non-null  float64
#  5   RatecodeID             74365 non-null  float64
#  6   store_and_fwd_flag     74365 non-null  object
#  7   PULocationID           90189 non-null  int32
#  8   DOLocationID           90189 non-null  int32
#  9   payment_type           90189 non-null  int64
#  10  fare_amount            90189 non-null  float64
#  11  extra                  90189 non-null  float64
#  12  mta_tax                90189 non-null  float64
#  13  tip_amount             90189 non-null  float64
#  14  tolls_amount           90189 non-null  float64
#  15  improvement_surcharge  90189 non-null  float64
#  16  total_amount           90189 non-null  float64
#  17  congestion_surcharge   74365 non-null  float64
#  18  Airport_fee            74365 non-null  float64
#  19  cbd_congestion_fee     90189 non-null  float64
# dtypes: datetime64[us](2), float64(13), int32(3), int64(1), object(1)
# memory usage: 13.4+ MB

# %%
# Pasamos las tablas a una base de datos SQL
con = sqlite3.connect(":memory:")

trips.to_sql("trips", con, index=False, if_exists="replace")
zones.to_sql("zones", con, index=False, if_exists="replace")
# Out:
# 265

# %% [markdown]
# ### Ejercicio 1
#
# Generar una tabla incorporando a la tabla de viajes una columna con la información del barrio de partida (sin perder ninguna fila)

# %%
trips_con_barrio = pd.read_sql_query("""
SELECT t.*, z.Borough AS barrio_inicio
FROM trips t 
LEFT JOIN zones z
ON t.PULocationID = z.LocationID 
""", con)
trips_con_barrio
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1             1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2             1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3             2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4             2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...         ...                  ...                   ...              ...
# 90184         2  2025-01-01 23:41:33   2025-01-01 23:58:46              NaN
# 90185         2  2025-01-01 23:02:52   2025-01-01 23:08:01              NaN
# 90186         2  2025-01-01 23:33:52   2025-01-01 23:48:39              NaN
# 90187         2  2025-01-01 23:34:59   2025-01-01 23:51:28              NaN
# 90188         2  2025-01-01 23:28:31   2025-01-01 23:51:27              NaN
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.60         1.0                  N           229
# 1               0.50         1.0                  N           236
# 2               0.60         1.0                  N           141
# 3               0.52         1.0                  N           244
# 4               0.66         1.0                  N           244
# ...              ...         ...                ...           ...
# 90184           6.09         NaN               None           197
# 90185           0.97         NaN               None           170
# 90186           6.00         NaN               None           219
# 90187           3.59         NaN               None           215
# 90188          13.32         NaN               None            28
#
#        DOLocationID  payment_type  ...  extra  mta_tax  tip_amount  \
# 0               237             1  ...    3.5      0.5        3.00
# 1               237             1  ...    3.5      0.5        2.02
# 2               141             1  ...    3.5      0.5        2.00
# 3               244             2  ...    1.0      0.5        0.00
# 4               116             2  ...    1.0      0.5        0.00
# ...             ...           ...  ...    ...      ...         ...
# 90184            36             0  ...    0.0      0.5        0.00
# 90185           234             0  ...    0.0      0.5        0.00
# 90186            86             0  ...    0.0      0.5        0.00
# 90187           258             0  ...    0.0      0.5        0.00
# 90188           242             0  ...    0.0      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0              0.00                    1.0         18.00
# 1              0.00                    1.0         12.12
# 2              0.00                    1.0         12.10
# 3              0.00                    1.0          9.70
# 4              0.00                    1.0          8.30
# ...             ...                    ...           ...
# 90184          0.00                    1.0          4.44
# 90185          0.00                    1.0          3.29
# 90186          0.00                    1.0         -1.84
# 90187          0.00                    1.0          3.06
# 90188          6.94                    1.0         -3.42
#
#        congestion_surcharge  Airport_fee  cbd_congestion_fee  barrio_inicio
# 0                       2.5          0.0                 0.0      Manhattan
# 1                       2.5          0.0                 0.0      Manhattan
# 2                       2.5          0.0                 0.0      Manhattan
# 3                       0.0          0.0                 0.0      Manhattan
# 4                       0.0          0.0                 0.0      Manhattan
# ...                     ...          ...                 ...            ...
# 90184                   NaN          NaN                 0.0         Queens
# 90185                   NaN          NaN                 0.0      Manhattan
# 90186                   NaN          NaN                 0.0         Queens
# 90187                   NaN          NaN                 0.0         Queens
# 90188                   NaN          NaN                 0.0         Queens
#
# [90189 rows x 21 columns]

# %% [markdown]
# ## Ejercicio 2
#
# Generar una tabla agregando a la tabla de viajes la información del barrio de partida, solo si esa información está disponible.

# %%
trips_con_barrio = pd.read_sql_query("""
SELECT t.*, z.Borough AS barrio_inicio
FROM trips t 
INNER JOIN zones z
ON t.PULocationID = z.LocationID 
""", con)
trips_con_barrio

# Se perdió alguna fila?
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1             1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2             1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3             2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4             2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...         ...                  ...                   ...              ...
# 90184         2  2025-01-01 23:41:33   2025-01-01 23:58:46              NaN
# 90185         2  2025-01-01 23:02:52   2025-01-01 23:08:01              NaN
# 90186         2  2025-01-01 23:33:52   2025-01-01 23:48:39              NaN
# 90187         2  2025-01-01 23:34:59   2025-01-01 23:51:28              NaN
# 90188         2  2025-01-01 23:28:31   2025-01-01 23:51:27              NaN
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.60         1.0                  N           229
# 1               0.50         1.0                  N           236
# 2               0.60         1.0                  N           141
# 3               0.52         1.0                  N           244
# 4               0.66         1.0                  N           244
# ...              ...         ...                ...           ...
# 90184           6.09         NaN               None           197
# 90185           0.97         NaN               None           170
# 90186           6.00         NaN               None           219
# 90187           3.59         NaN               None           215
# 90188          13.32         NaN               None            28
#
#        DOLocationID  payment_type  ...  extra  mta_tax  tip_amount  \
# 0               237             1  ...    3.5      0.5        3.00
# 1               237             1  ...    3.5      0.5        2.02
# 2               141             1  ...    3.5      0.5        2.00
# 3               244             2  ...    1.0      0.5        0.00
# 4               116             2  ...    1.0      0.5        0.00
# ...             ...           ...  ...    ...      ...         ...
# 90184            36             0  ...    0.0      0.5        0.00
# 90185           234             0  ...    0.0      0.5        0.00
# 90186            86             0  ...    0.0      0.5        0.00
# 90187           258             0  ...    0.0      0.5        0.00
# 90188           242             0  ...    0.0      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0              0.00                    1.0         18.00
# 1              0.00                    1.0         12.12
# 2              0.00                    1.0         12.10
# 3              0.00                    1.0          9.70
# 4              0.00                    1.0          8.30
# ...             ...                    ...           ...
# 90184          0.00                    1.0          4.44
# 90185          0.00                    1.0          3.29
# 90186          0.00                    1.0         -1.84
# 90187          0.00                    1.0          3.06
# 90188          6.94                    1.0         -3.42
#
#        congestion_surcharge  Airport_fee  cbd_congestion_fee  barrio_inicio
# 0                       2.5          0.0                 0.0      Manhattan
# 1                       2.5          0.0                 0.0      Manhattan
# 2                       2.5          0.0                 0.0      Manhattan
# 3                       0.0          0.0                 0.0      Manhattan
# 4                       0.0          0.0                 0.0      Manhattan
# ...                     ...          ...                 ...            ...
# 90184                   NaN          NaN                 0.0         Queens
# 90185                   NaN          NaN                 0.0      Manhattan
# 90186                   NaN          NaN                 0.0         Queens
# 90187                   NaN          NaN                 0.0         Queens
# 90188                   NaN          NaN                 0.0         Queens
#
# [90189 rows x 21 columns]

# %% [markdown]
# ¿Se perdió alguna fila?

# %% [markdown]
# ### Ejercicio 3
#
# Para cada zona, calcular la cantidad total de viajes que comienzan en esa zona, solo en el caso de que haya algún viaje.

# %%
# Primero obtenemos el listado sin calcular cantidades
listado_de_viajes_por_zona = pd.read_sql_query("""
SELECT
    z.*, t.trip_distance
FROM zones AS z
INNER JOIN trips AS t
    ON t.PULocationID = z.LocationID
""", con)

# %%
listado_de_viajes_por_zona
# Out:
#        LocationID Borough            Zone service_zone  trip_distance
# 0               1     EWR  Newark Airport          EWR           0.00
# 1               1     EWR  Newark Airport          EWR           0.00
# 2               1     EWR  Newark Airport          EWR           0.00
# 3               1     EWR  Newark Airport          EWR           0.00
# 4               1     EWR  Newark Airport          EWR           0.00
# ...           ...     ...             ...          ...            ...
# 90184         265    None  Outside of NYC         None          29.15
# 90185         265    None  Outside of NYC         None          47.05
# 90186         265    None  Outside of NYC         None          61.10
# 90187         265    None  Outside of NYC         None          94.88
# 90188         265    None  Outside of NYC         None         122.77
#
# [90189 rows x 5 columns]

# %%
# Ahora agregamos (siempre agrupamos por la tabla de la izquierda, aunque en SQLite en este caso se puede agrupar por cualquiera de las dos)
viajes_por_zona = pd.read_sql_query("""
SELECT
    z.*, COUNT(*) AS n_viajes
FROM zones AS z
INNER JOIN trips AS t
    ON t.PULocationID = z.LocationID
GROUP BY z.LocationID
""", con)

# %%
viajes_por_zona
# Out:
#      LocationID        Borough                     Zone service_zone  n_viajes
# 0             1            EWR           Newark Airport          EWR        21
# 1             3          Bronx  Allerton/Pelham Gardens    Boro Zone         9
# 2             4      Manhattan            Alphabet City  Yellow Zone       269
# 3             5  Staten Island            Arden Heights    Boro Zone         1
# 4             6  Staten Island  Arrochar/Fort Wadsworth    Boro Zone         2
# ..          ...            ...                      ...          ...       ...
# 238         261      Manhattan       World Trade Center  Yellow Zone       629
# 239         262      Manhattan           Yorkville East  Yellow Zone       758
# 240         263      Manhattan           Yorkville West  Yellow Zone      1701
# 241         264        Unknown                     None         None       166
# 242         265           None           Outside of NYC         None       117
#
# [243 rows x 5 columns]

# %% [markdown]
# ### Ejercicio 4
#
# Y si quiero la información para todas las zonas, aunque haya 0 viajes?

# %%
# Funciona esto??
viajes_por_zona = pd.read_sql_query("""
SELECT
    z.*,
    COUNT(*) AS n_trips
FROM zones AS z
LEFT JOIN trips AS t
    ON t.PULocationID = z.LocationID
GROUP BY z.LocationID
""", con)

# %%
viajes_por_zona
# Out:
#      LocationID        Borough                     Zone service_zone  n_trips
# 0             1            EWR           Newark Airport          EWR       21
# 1             2         Queens              Jamaica Bay    Boro Zone        1
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone        9
# 3             4      Manhattan            Alphabet City  Yellow Zone      269
# 4             5  Staten Island            Arden Heights    Boro Zone        1
# ..          ...            ...                      ...          ...      ...
# 260         261      Manhattan       World Trade Center  Yellow Zone      629
# 261         262      Manhattan           Yorkville East  Yellow Zone      758
# 262         263      Manhattan           Yorkville West  Yellow Zone     1701
# 263         264        Unknown                     None         None      166
# 264         265           None           Outside of NYC         None      117
#
# [265 rows x 5 columns]

# %% [markdown]
# Está bien la respuesta? Por qué pasa esto? Cómo la podemos arreglar?
#
# **Sugerencia:** tener en cuenta que count() solo cuenta valores no nulos.

# %%
# Funciona esto??
viajes_por_zona = pd.read_sql_query("""
SELECT
    z.*,
    COUNT(z.trip_distance) AS n_trips
FROM zones AS z
LEFT JOIN trips AS t
    ON t.PULocationID = z.LocationID
GROUP BY z.LocationID
""", con)
viajes_por_zona
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/venv_labo_datos/lib/python3.12/site-packages/pandas/io/sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such column: z.trip_distance
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Funciona esto??
# ----> 2 viajes_por_zona = pd.read_sql_query("""
#       3 SELECT
#       4     z.*,
#       5     COUNT(z.trip_distance) AS n_trips
#       6 FROM zones AS z
#       7 LEFT JOIN trips AS t
#       8     ON t.PULocationID = z.LocationID
#       9 GROUP BY z.LocationID
#      10 """, con)
#      11 viajes_por_zona
#
# File ~/miniconda3/envs/venv_labo_datos/lib/python3.12/site-packages/pandas/io/sql.py:528, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     525 assert dtype_backend is not lib.no_default
#     527 with pandasSQL_builder(con) as pandas_sql:
# --> 528     return pandas_sql.read_query(
#     529         sql,
#     530         index_col=index_col,
#     531         params=params,
#     532         coerce_float=coerce_float,
#     533         parse_dates=parse_dates,
#     534         chunksize=chunksize,
#     535         dtype=dtype,
#     536         dtype_backend=dtype_backend,
#     537     )
#
# File ~/miniconda3/envs/venv_labo_datos/lib/python3.12/site-packages/pandas/io/sql.py:2728, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2717 def read_query(
#    2718     self,
#    2719     sql,
#    (...)   2726     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2727 ) -> DataFrame | Iterator[DataFrame]:
# -> 2728     cursor = self.execute(sql, params)
#    2729     columns = [col_desc[0] for col_desc in cursor.description]
#    2731     if chunksize is not None:
#
# File ~/miniconda3/envs/venv_labo_datos/lib/python3.12/site-packages/pandas/io/sql.py:2676, in SQLiteDatabase.execute(self, sql, params)
#    2673     raise ex from inner_exc
#    2675 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2676 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     z.*,
#     COUNT(z.trip_distance) AS n_trips
# FROM zones AS z
# LEFT JOIN trips AS t
#     ON t.PULocationID = z.LocationID
# GROUP BY z.LocationID
# ': no such column: z.trip_distance

# %% [markdown]
# ### Ejercicio 5
#
# Generar una tabla agregando a la tabla de viajes la información del barrio de partida y barrio de llegada (sin perder ninguna fila)

# %%
# Modificamos el ejercio 1
trips_con_barrio = pd.read_sql_query("""
SELECT
    t.*, z1.Borough as barrio_partida, z2.Borough as barrio_destino
FROM trips AS t
LEFT JOIN zones AS z1
    ON t.PULocationID = z1.LocationID
LEFT JOIN zones AS z2
    ON t.DOLocationID = z2.LocationID
""", con)
trips_con_barrio
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2025-01-01 00:18:38   2025-01-01 00:26:59              1.0
# 1             1  2025-01-01 00:32:40   2025-01-01 00:35:13              1.0
# 2             1  2025-01-01 00:44:04   2025-01-01 00:46:01              1.0
# 3             2  2025-01-01 00:14:27   2025-01-01 00:20:01              3.0
# 4             2  2025-01-01 00:21:34   2025-01-01 00:25:06              3.0
# ...         ...                  ...                   ...              ...
# 90184         2  2025-01-01 23:41:33   2025-01-01 23:58:46              NaN
# 90185         2  2025-01-01 23:02:52   2025-01-01 23:08:01              NaN
# 90186         2  2025-01-01 23:33:52   2025-01-01 23:48:39              NaN
# 90187         2  2025-01-01 23:34:59   2025-01-01 23:51:28              NaN
# 90188         2  2025-01-01 23:28:31   2025-01-01 23:51:27              NaN
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               1.60         1.0                  N           229
# 1               0.50         1.0                  N           236
# 2               0.60         1.0                  N           141
# 3               0.52         1.0                  N           244
# 4               0.66         1.0                  N           244
# ...              ...         ...                ...           ...
# 90184           6.09         NaN               None           197
# 90185           0.97         NaN               None           170
# 90186           6.00         NaN               None           219
# 90187           3.59         NaN               None           215
# 90188          13.32         NaN               None            28
#
#        DOLocationID  payment_type  ...  mta_tax  tip_amount  tolls_amount  \
# 0               237             1  ...      0.5        3.00          0.00
# 1               237             1  ...      0.5        2.02          0.00
# 2               141             1  ...      0.5        2.00          0.00
# 3               244             2  ...      0.5        0.00          0.00
# 4               116             2  ...      0.5        0.00          0.00
# ...             ...           ...  ...      ...         ...           ...
# 90184            36             0  ...      0.5        0.00          0.00
# 90185           234             0  ...      0.5        0.00          0.00
# 90186            86             0  ...      0.5        0.00          0.00
# 90187           258             0  ...      0.5        0.00          0.00
# 90188           242             0  ...      0.5        0.00          6.94
#
#        improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                        1.0         18.00                   2.5          0.0
# 1                        1.0         12.12                   2.5          0.0
# 2                        1.0         12.10                   2.5          0.0
# 3                        1.0          9.70                   0.0          0.0
# 4                        1.0          8.30                   0.0          0.0
# ...                      ...           ...                   ...          ...
# 90184                    1.0          4.44                   NaN          NaN
# 90185                    1.0          3.29                   NaN          NaN
# 90186                    1.0         -1.84                   NaN          NaN
# 90187                    1.0          3.06                   NaN          NaN
# 90188                    1.0         -3.42                   NaN          NaN
#
#        cbd_congestion_fee  barrio_partida  barrio_destino
# 0                     0.0       Manhattan       Manhattan
# 1                     0.0       Manhattan       Manhattan
# 2                     0.0       Manhattan       Manhattan
# 3                     0.0       Manhattan       Manhattan
# 4                     0.0       Manhattan       Manhattan
# ...                   ...             ...             ...
# 90184                 0.0          Queens        Brooklyn
# 90185                 0.0       Manhattan       Manhattan
# 90186                 0.0          Queens          Queens
# 90187                 0.0          Queens          Queens
# 90188                 0.0          Queens           Bronx
#
# [90189 rows x 22 columns]

# %% [markdown]
# # Ejercicio 6
# Para cada barrio (Borough), calcular la distancia promedio de los viajes que empiezan en en ese barrio, el precio promedio y la cantidad de viajes.

# %%
estadisticos = pd.read_sql_query("""
select
    z.Borough,
    avg(t.total_amount),
    avg(t.trip_distance),
    COUNT(t.trip_distance) as n_trips
from zones z
left join trips t
    on t.PULocationID = z.LocationID
group by z.Borough
""", con)

# %%
estadisticos
# Out:
#          Borough  avg(t.total_amount)  avg(t.trip_distance)  n_trips
# 0           None            78.630085              4.898889      117
# 1          Bronx             8.006910            197.364741      793
# 2       Brooklyn            17.593245              5.448581     3405
# 3            EWR            78.450000              0.404762       21
# 4      Manhattan            21.677683              3.732891    74691
# 5         Queens            53.771755             11.362911    10981
# 6  Staten Island             8.336667             12.292667       15
# 7        Unknown            29.415663              3.717892      166
